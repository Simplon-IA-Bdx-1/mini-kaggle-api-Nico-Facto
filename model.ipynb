# %%
from pycaret.classification import *
import pandas as pd

# %%
df = pd.read_csv("train2.csv", index_col=0)

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0             1                 1                              0.766127   45
# 1             2                 0                              0.957151   40
# 2             3                 0                              0.658180   38
# 3             4                 0                              0.233810   30
# 4             5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# ...

# %%
exp_clf = setup(df, target = 'SeriousDlqin2yrs', silent=True, session_id=129)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_b717628c_d0d6_11ea_ab32_54ee753269c2row4_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_b717628c_d0d6_11ea_ab32_54ee753269c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b717628c_d0d6_11ea_ab32_54ee753269c2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b717628c_d0d6_11ea_ab32_54ee753269c2row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_b717628c_d0d6_11ea_ab32_54ee753269c2row0_col1" class="data row0 col1" >129</td>
#             </tr>
#             <tr>
#                         <th id="T_b717628c_d0d6_11ea_ab32_54ee753269c2level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
compare_models(blacklist=['xgboost'])
# Out:
# <style  type="text/css" >
#     #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2 th {
#           text-align: left;
#     }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row0_col0 {
#             text-align:  left;
#         }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row0_col4 {
#             : ;
#             text-align:  left;
#         }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_7de1b6ee_d0d4_11ea_ba60_54ee753269c2row1_col0 {
# ...

# %%
model = create_model('gbc')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa
# 0       0.9349  0.8656  0.1777  0.5299  0.2661  0.2408
# 1       0.9360  0.8550  0.1457  0.5795  0.2329  0.2118
# 2       0.9377  0.8644  0.1857  0.6075  0.2845  0.2614
# 3       0.9366  0.8639  0.1743  0.5810  0.2681  0.2449
# 4       0.9360  0.8542  0.1571  0.5729  0.2466  0.2244
# 5       0.9366  0.8634  0.1800  0.5780  0.2745  0.2508
# 6       0.9381  0.8619  0.1914  0.6147  0.2919  0.2688
# 7       0.9343  0.8556  0.1971  0.5188  0.2857  0.2585
# 8       0.9354  0.8494  0.1743  0.5495  0.2646  0.2403
# 9       0.9362  0.8566  0.1777  0.5636  0.2702  0.2461
# Mean    0.9362  0.8590  0.1761  0.5695  0.2685  0.2448
# SD      0.0011  0.0052  0.0144  0.0289  0.0171  0.0162

# %%
Prod_model = finalize_model(model)

# %%
save_model(Prod_model, 'Prod_model')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
df_test = pd.read_csv("test2.csv", index_col=0)

# %%
df_test
# Out:
#         Unnamed: 0.1  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 75001          75002                 0                              0.214896
# 75002          75003                 1                              0.081459
# 75003          75004                 0                              0.025839
# 75004          75005                 0                              0.026099
# 75005          75006                 0                              0.090527
# ...              ...               ...                                   ...
# 149995        149996                 0                              0.040674
# 149996        149997                 0                              0.299745
# 149997        149998                 0                              0.246044
# 149998        149999                 0                              0.000000
# 149999        150000                 0                              0.850283
#
# ...

# %%
saved_model = load_model('Prod_model')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
predictions = predict_model(saved_model, data=df_test)

# %%
type(predictions)
# Out:
# pandas.core.frame.DataFrame

# %%
predictions
# Out:
#        Unnamed: 0.1  SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  \
# 0             75002                 0                              0.214896
# 1             75003                 1                              0.081459
# 2             75004                 0                              0.025839
# 3             75005                 0                              0.026099
# 4             75006                 0                              0.090527
# ...             ...               ...                                   ...
# 74994        149996                 0                              0.040674
# 74995        149997                 0                              0.299745
# 74996        149998                 0                              0.246044
# 74997        149999                 0                              0.000000
# 74998        150000                 0                              0.850283
#
# ...
